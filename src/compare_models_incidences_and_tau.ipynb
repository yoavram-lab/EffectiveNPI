# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %load_ext autoreload
# %autoreload
exec(open("plot_utils.py").read())
# Out:
# /Users/adsurbum/anaconda2/envs/py371/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import matplotlib.backends.backend_pdf
countries =  ['Austria', 'Belgium', 'Denmark', 'France', 'Germany', 'Italy', 'Norway', 'Spain', 'Sweden', 
              'Switzerland', 'United_Kingdom', 'Wuhan']

pdf = matplotlib.backends.backend_pdf.PdfPages('tau_and_incidences-dates.pdf')



data = load_data(file_name, country_name,0.6,100)
for c in countries:
    print(c)
    country_name=c
    file_name1 = '../output/2020-05-14-n1-normal-1M/inference/{}.npz'.format(country_name)
    file_name2 = '../output/2020-05-27-more1week/inference/{}.npz'.format(country_name)
    file_name3 = '../output/2020-05-26-more2weeks/inference/{}.npz'.format(country_name)
    file_name4 = '../output/2020-05-25-normal-endapril-1M/inference/{}.npz'.format(country_name)

    fig = plt.figure(figsize=(33, 11))
    gs = gridspec.GridSpec(2,4)
    
    load_data(file_name1, c)
    plot_incidences(fig.add_subplot(gs[0, 0]), title=c)
    plot_τ(fig.add_subplot(gs[1, 0]))

    load_data(file_name2, c)
    plot_incidences(fig.add_subplot(gs[0, 1]), title=c)
    plot_τ(fig.add_subplot(gs[1, 1]))
    
    load_data(file_name3, c)
    plot_incidences(fig.add_subplot(gs[0, 2]), title=c)
    plot_τ(fig.add_subplot(gs[1, 2]))

    load_data(file_name4, c)
    plot_incidences(fig.add_subplot(gs[0, 3]), title=c)
    plot_τ(fig.add_subplot(gs[1, 3]))
    
#     plt.title(c)
    plt.show()
    pdf.savefig(fig,bbox_inches="tight")

pdf.close()
# Out:
# Austria
# Belgium
# Denmark
# France
# Germany
# Italy
# Norway
# Spain
# Sweden
# Switzerland
# United_Kingdom
# Wuhan
