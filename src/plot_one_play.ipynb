# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %load_ext autoreload
# %autoreload
exec(open("plot_utils.py").read())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
country_name = 'Italy'
file_name = '../output-tmp/2020-05-14-test/inference/{}.npz'.format(country_name)
data = load_data(file_name, country_name)
plot_all();
# plot_incidences()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-c352a465ccca> in <module>
#       2 file_name = '../output-tmp/2020-05-14-test/inference/{}.npz'.format(country_name)
#       3 data = load_data(file_name, country_name)
# ----> 4 plot_all();
#       5 # plot_incidences()
#
# <string> in plot_all()
#
# <string> in plot_incidences_and_dates(ax)
#
# ValueError: 'τ' is not in list
