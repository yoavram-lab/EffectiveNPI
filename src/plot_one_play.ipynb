# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %load_ext autoreload
# %autoreload
exec(open("plot_utils.py").read())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
country_name = 'Italy'
file_name = '../output/2020-05-15-notau-up-to-10March-1M/inference/{}.npz'.format(country_name)
data = load_data(file_name, country_name)
# plot_all();
# plot_hists();
plot_incidences()

# %%
plot_incidences(title=country_name)
